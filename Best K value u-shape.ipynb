# %%
import pandas as pd
import numpy as np
import sklearn

# %%
pip install mlxtend
# Out:
# ...
#                                               0.0/1.4 MB ? eta -:--:--
#      ------                                   0.2/1.4 MB 7.3 MB/s eta 0:00:01
#      ----------------                         0.6/1.4 MB 7.7 MB/s eta 0:00:01
#      -----------------------------            1.1/1.4 MB 8.4 MB/s eta 0:00:01
#      ---------------------------------------  1.4/1.4 MB 8.3 MB/s eta 0:00:01
#      ---------------------------------------- 1.4/1.4 MB 7.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from mlxtend.plotting import plot_decision_regions

# %%
data = pd.read_csv(r"D:\Datasets\Machine Learning Dataset\Multiple CSV\1.ushape.csv")

# %%
data
# Out:
#     3.159499363321345566e-02  9.869877579082642072e-01  \
# 0                   2.115098                 -0.046244
# 1                   0.882490                 -0.075756
# 2                  -0.055144                 -0.037332
# 3                   0.829545                 -0.539321
# 4                   2.112857                  0.662084
# ..                       ...                       ...
# 94                  1.699453                  0.587720
# 95                  0.218623                 -0.652521
# 96                  0.952914                 -0.419766
# 97                 -1.318500                  0.423112
# 98                 -1.296818                  0.184147
#
#     0.000000000000000000e+00
# 0                        1.0
# 1                        0.0
# 2                        1.0
# 3                        1.0
# 4                        1.0
# ..                       ...
# 94                       1.0
# 95                       1.0
# 96                       1.0
# ...

# %%
fv = data.iloc[:,:2]
cv = data.iloc[:,-1]

# %% [markdown]
# ## Decision Region

# %%
import matplotlib.pyplot as plt

# %%
for i in range(1,20,2):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(fv,cv)
    print(i)
    plot_decision_regions(X=fv.values, y=cv.values.astype(int),clf=knn,)
    plt.show()
# Out:
# 1
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 3
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 5
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 7
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 9
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 11
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(fv,cv, test_size=0.2, random_state=10, stratify=cv)
x_trainf,x_cv,y_trainf,y_cv= train_test_split(x_train,y_train, test_size=0.2, random_state=10, stratify=y_train)

# %%
y_cv
# Out:
# 90    0.0
# 67    0.0
# 32    1.0
# 26    1.0
# 28    1.0
# 25    0.0
# 47    0.0
# 85    1.0
# 20    1.0
# 73    1.0
# 86    0.0
# 46    0.0
# 16    0.0
# 94    1.0
# 54    1.0
# 80    0.0
# Name: 0.000000000000000000e+00, dtype: float64

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
k = []
acc =[]
err = []
for n in range(1,20,2):
    knn = KNeighborsClassifier(n_neighbors=n)
    model = knn.fit(x_trainf,y_trainf)
    predicted = model.predict(x_cv)
    k.append(n)
    acc.append(accuracy_score(y_cv,predicted))
    err.append(1-accuracy_score(y_cv,predicted))

# %%
plt.plot(k,acc)

# %% [markdown]
# * The best value for k is 3 to 9
